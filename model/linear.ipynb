# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('../15_modified_data/train_data.csv')
train.head()
# Out:
#   trip_start_timestamp   trip_end_timestamp  trip_seconds  trip_miles  fare  \
# 0  2019-09-24 06:30:00  2019-09-24 06:45:00         802.0    6.183132  10.0
# 1  2019-07-30 11:45:00  2019-07-30 12:30:00        2349.0   18.248731  35.0
# 2  2018-11-17 01:15:00  2018-11-17 01:30:00         684.0    5.277118  10.0
# 3  2019-12-09 12:00:00  2019-12-09 12:15:00         698.0    3.079843   7.5
# 4  2018-12-17 15:00:00  2018-12-17 15:00:00         812.0    2.996371   7.5
#
#    tip  additional_charges  shared_trip_authorized  trips_pooled        date  \
# 0    3                2.55                   False             1  2019-09-24
# 1    0                8.11                   False             1  2019-07-30
# 2    0                2.50                   False             1  2018-11-17
# 3    1                2.55                   False             1  2019-12-09
# 4    0                2.50                   False             1  2018-12-17
#
# ...

# %%
y = train['tip']
len(y)
# Out:
# 83703

# %%
month_map = {'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6, 'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12}
train['month_int'] = train['month'].map(month_map)
day_map = {'Monday': 1, 'Tuesday': 2, 'Wednesday': 3, 'Thursday': 4, 'Friday': 5, 'Saturday': 6, 'Sunday': 7}
train['day_ofweek_int'] = train['day_of_week'].map(day_map)
# train['day_ofweek_int'].trainue_counts()
train.drop(['day_of_week', 'month' ], axis=1, inplace=True)
X = pd.get_dummies(train, columns = ['dropoff_community_name', 'pickup_community_name'])
X.drop(['nonzero_tip', 'tip', 'trip_start_timestamp', 'trip_end_timestamp', 'date' ], axis=1, inplace=True)

# %%
# X = pd.get_dummies(train, columns = ['dropoff_community_name', 'pickup_community_name'])
# X.head()

# %%
# X.drop(['tip', 'nonzero_tip', 'trip_start_timestamp', 'trip_end_timestamp', 'date' ], axis=1, inplace=True)

# %%
# month_map = {'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6, 'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12}
# X['month_int'] = X['month'].map(month_map)

# %%
# day_map = {'Monday': 1, 'Tuesday': 2, 'Wednesday': 3, 'Thursday': 4, 'Friday': 5, 'Saturday': 6, 'Sunday': 7}
# X['day_ofweek_int'] = X['day_of_week'].map(day_map)
# X['day_ofweek_int'].value_counts()

# %%
# X.drop(['day_of_week', 'month' ], axis=1, inplace=True)

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
# reg = LinearRegression().fit(X_train, y_train)

# %%
# reg.score(X_test, y_test)

# %%
# ypred_lr = reg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import r2_score

# %%
# r2_score(ypred_lr, y_test)

# %%
import imblearn
from imblearn.under_sampling import RandomUnderSampler
import collections
from imblearn.over_sampling import RandomOverSampler

# %%
# ros = RandomOverSampler(random_state=42)
# x_ros, y_ros = ros.fit_resample(X, y)

# %%
# X_train2, X_test2, y_train2, y_test2 = train_test_split(x_ros, y_ros, test_size=0.2, random_state=0)

# %%
# reg2 = LinearRegression().fit(X_train2, y_train2)
# reg2.score(X_test2, y_test2)

# %%
# ypred_lr2 = reg2.predict(X_test2)
# r2_score(ypred_lr2, y_test2)

# %%
# rus = RandomUnderSampler(random_state=42, replacement=True)
# x_rus, y_rus = rus.fit_resample(X, y)
# X_train1, X_test1, y_train1, y_test1 = train_test_split(x_rus, y_rus, test_size=0.2, random_state=0)

# %%
# reg3 = LinearRegression().fit(X_train1, y_train1)
# reg3.score(X_test1, y_test1)

# %%
# ypred_lr2 = reg3.predict(X_test1)
# r2_score(ypred_lr2, y_test1)

# %%
# X[X['tip'] > 1]
new = pd.concat([y, X], axis=1)
new.head()
tippers = new[new['tip']>1].copy()
tippers.head()
# tippers.head()
# Out:
#     tip  trip_seconds  trip_miles  fare  additional_charges  \
# 0     3         802.0    6.183132  10.0                2.55
# 8     4        1921.0   15.367562  22.5                7.55
# 13    2        1687.0    7.392372  15.0                2.50
# 17    5         505.0    1.853181   5.0                2.55
# 18    3         599.0    1.890000   5.0                2.55
#
#     shared_trip_authorized  trips_pooled  max_temp  min_temp   precip  ...  \
# 0                    False             1     80.06     80.06  0.00000  ...
# 8                    False             1     95.00     95.00  0.00000  ...
# 13                   False             1     48.92     48.92  0.19685  ...
# 17                   False             1     87.98     87.98  0.00000  ...
# 18                   False             1     27.14     27.14  0.00000  ...
#
#     pickup_community_name_WASHINGTON HEIGHTS  \
# 0                                          0
# 8                                          0
# ...

# %%
tippers_y = tippers['tip']

tippers_X = tippers.drop(['tip'], axis = 1)

# %%
tippers_X.head()
# Out:
#     trip_seconds  trip_miles  fare  additional_charges  \
# 0          802.0    6.183132  10.0                2.55
# 8         1921.0   15.367562  22.5                7.55
# 13        1687.0    7.392372  15.0                2.50
# 17         505.0    1.853181   5.0                2.55
# 18         599.0    1.890000   5.0                2.55
#
#     shared_trip_authorized  trips_pooled  max_temp  min_temp   precip  snow  \
# 0                    False             1     80.06     80.06  0.00000   0.0
# 8                    False             1     95.00     95.00  0.00000   0.0
# 13                   False             1     48.92     48.92  0.19685   0.0
# 17                   False             1     87.98     87.98  0.00000   0.0
# 18                   False             1     27.14     27.14  0.00000   0.0
#
#     ...  pickup_community_name_WASHINGTON HEIGHTS  \
# 0   ...                                         0
# 8   ...                                         0
# ...

# %%
# reg_tip= LinearRegression().fit(X_train, y_train)
# reg_tip.score(X_test2, y_test2)
# # reg_tip = LinearRegression().fit(X_train2, y_train2)
# # reg_tip.score(X_test2, y_test2)

# %%
# ypred_lr2 = reg_tip.predict(X_test2)
# r2_score(ypred_lr2, y_test2)

# %%
val = pd.read_csv('../15_modified_data/val_data.csv')
val.head()
# Out:
#   trip_start_timestamp   trip_end_timestamp  trip_seconds  trip_miles  fare  \
# 0  2018-11-18 07:00:00  2018-11-18 07:00:00         100.0    0.572958   2.5
# 1  2020-01-22 09:30:00  2020-01-22 09:45:00         986.0    4.142381  10.0
# 2  2018-11-26 18:45:00  2018-11-26 19:00:00         584.0    1.830871   5.0
# 3  2018-12-30 15:15:00  2018-12-30 15:30:00         819.0    4.976403  10.0
# 4  2019-07-01 23:45:00  2019-07-02 00:00:00        1162.0    8.918748  15.0
#
#    tip  additional_charges  shared_trip_authorized  trips_pooled        date  \
# 0    0                2.50                   False             1  2018-11-18
# 1    0                4.83                   False             1  2020-01-22
# 2    1                2.50                   False             1  2018-11-26
# 3    0                2.50                   False             1  2018-12-30
# 4    2                2.55                   False             1  2019-07-01
#
# ...

# %%
val_y = val['nonzero_tip']
len(val_y)
# Out:
# 11957

# %%
month_map = {'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6, 'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12}
val['month_int'] = val['month'].map(month_map)
day_map = {'Monday': 1, 'Tuesday': 2, 'Wednesday': 3, 'Thursday': 4, 'Friday': 5, 'Saturday': 6, 'Sunday': 7}
val['day_ofweek_int'] = val['day_of_week'].map(day_map)
# val['day_ofweek_int'].value_counts()
val.drop(['day_of_week', 'month' ], axis=1, inplace=True)
val_X = pd.get_dummies(val, columns = ['dropoff_community_name', 'pickup_community_name'])
val_X.drop(['nonzero_tip', 'tip', 'trip_start_timestamp', 'trip_end_timestamp', 'date' ], axis=1, inplace=True)

# %%
val_X = pd.get_dummies(val, columns = ['dropoff_community_name', 'pickup_community_name'])
val_X.drop(['nonzero_tip', 'tip', 'trip_start_timestamp', 'trip_end_timestamp', 'date' ], axis=1, inplace=True)

# %%
tippers_X.drop(['dropoff_community_name_RIVERDALE'], axis = 1, inplace=True)

# %%
len(tippers_X)
len(val_X)
# Out:
# 11957

# %%
reg_tip= LinearRegression().fit(tippers_X, tippers_y)
reg_tip.score(val_X,val_y)
# reg_tip = LinearRegression().fit(X_train2, y_train2)
# reg_tip.score(X_test2, y_test2)
# Out:
# -35212560.05361401

# %%
ypred_lr2 = reg_tip.predict(val_X)
r2_score(ypred_lr2, val_y)
# Out:
# -0.00044259263524493164

# %%
val_X.head()
# Out:
#    trip_seconds  trip_miles  fare  additional_charges  shared_trip_authorized  \
# 0         100.0    0.572958   2.5                2.50                   False
# 1         986.0    4.142381  10.0                4.83                   False
# 2         584.0    1.830871   5.0                2.50                   False
# 3         819.0    4.976403  10.0                2.50                   False
# 4        1162.0    8.918748  15.0                2.55                   False
#
#    trips_pooled  max_temp  min_temp    precip  snow  ...  \
# 0             1     37.94     37.94  0.314961   0.0  ...
# 1             1     35.06     35.06  0.000000   0.0  ...
# 2             1     33.98     33.98  1.181102   0.0  ...
# 3             1     37.04     37.04  0.000000   0.0  ...
# 4             1     91.04     91.04  0.000000   0.0  ...
#
#    pickup_community_name_WASHINGTON HEIGHTS  \
# 0                                         0
# 1                                         0
# ...

# %%
tippers_X.head()
# Out:
#     trip_seconds  trip_miles  fare  additional_charges  \
# 0          802.0    6.183132  10.0                2.55
# 8         1921.0   15.367562  22.5                7.55
# 13        1687.0    7.392372  15.0                2.50
# 17         505.0    1.853181   5.0                2.55
# 18         599.0    1.890000   5.0                2.55
#
#     shared_trip_authorized  trips_pooled  max_temp  min_temp   precip  snow  \
# 0                    False             1     80.06     80.06  0.00000   0.0
# 8                    False             1     95.00     95.00  0.00000   0.0
# 13                   False             1     48.92     48.92  0.19685   0.0
# 17                   False             1     87.98     87.98  0.00000   0.0
# 18                   False             1     27.14     27.14  0.00000   0.0
#
#     ...  pickup_community_name_WASHINGTON HEIGHTS  \
# 0   ...                                         0
# 8   ...                                         0
# ...

# %%
import statsmodels.formula.api as smf

# %%
train.head()
# Out:
#   trip_start_timestamp   trip_end_timestamp  trip_seconds  trip_miles  fare  \
# 0  2019-09-24 06:30:00  2019-09-24 06:45:00         802.0    6.183132  10.0
# 1  2019-07-30 11:45:00  2019-07-30 12:30:00        2349.0   18.248731  35.0
# 2  2018-11-17 01:15:00  2018-11-17 01:30:00         684.0    5.277118  10.0
# 3  2019-12-09 12:00:00  2019-12-09 12:15:00         698.0    3.079843   7.5
# 4  2018-12-17 15:00:00  2018-12-17 15:00:00         812.0    2.996371   7.5
#
#    tip  additional_charges  shared_trip_authorized  trips_pooled        date  \
# 0    3                2.55                   False             1  2019-09-24
# 1    0                8.11                   False             1  2019-07-30
# 2    0                2.50                   False             1  2018-11-17
# 3    1                2.55                   False             1  2019-12-09
# 4    0                2.50                   False             1  2018-12-17
#
# ...

# %%
train.columns
# Out:
# Index(['trip_start_timestamp', 'trip_end_timestamp', 'trip_seconds',
#        'trip_miles', 'fare', 'tip', 'additional_charges',
#        'shared_trip_authorized', 'trips_pooled', 'date', 'max_temp',
#        'min_temp', 'precip', 'snow', 'snow_depth', 'wind_speed',
#        'pickup_community_name', 'dropoff_community_name', 'year', 'day',
#        'hour', 'weekend', 'nonzero_tip', 'month_int', 'day_ofweek_int'],
#       dtype='object')

# %%
model = smf.ols('tip ~ trip_miles + fare + trip_seconds + weekend + hour', tippers).fit()

# %%
train_new = train[train['tip'] > 0 ]

# %%
model1 = smf.ols('tip ~ trip_miles + fare + trip_seconds + C(pickup_community_name) + C(dropoff_community_name) + C(day) + wind_speed + trips_pooled + additional_charges + C(month_int)', train_new).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    tip   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.402
# Method:                 Least Squares   F-statistic:                     52.09
# Date:                Sun, 10 Apr 2022   Prob (F-statistic):               0.00
# Time:                        15:08:56   Log-Likelihood:                -28511.
# No. Observations:               15049   AIC:                         5.742e+04
# Df Residuals:                   14850   BIC:                         5.894e+04
# Df Model:                         198
# Covariance Type:            nonrobust
# ...
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# ...

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    tip   R-squared:                       0.357
# Model:                            OLS   Adj. R-squared:                  0.357
# Method:                 Least Squares   F-statistic:                     1245.
# Date:                Sun, 10 Apr 2022   Prob (F-statistic):               0.00
# Time:                        15:02:56   Log-Likelihood:                -21585.
# No. Observations:               11221   AIC:                         4.318e+04
# Df Residuals:                   11215   BIC:                         4.323e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
final = pd.read_csv('../15_modified_data/final_data.csv')
final.head()
# Out:
#    Unnamed: 0 trip_start_timestamp       trip_end_timestamp  trip_seconds  \
# 0           0  2018-11-01 19:45:00  2018-11-01T20:00:00.000         576.0
# 1           1  2018-11-01 18:00:00  2018-11-01T18:00:00.000         500.0
# 2           2  2018-11-01 12:30:00  2018-11-01T12:45:00.000         503.0
# 3           3  2018-11-01 13:15:00  2018-11-01T13:30:00.000        1444.0
# 4           4  2018-11-01 12:00:00  2018-11-01T12:00:00.000         388.0
#
#    trip_miles  pickup_community_area  dropoff_community_area  fare  tip  \
# 0    2.691298                      8                      24   7.5    0
# 1    1.572838                     61                      68   5.0    0
# 2    1.813330                      2                      77   7.5    0
# 3   10.235455                     32                       1  17.5    5
# 4    0.833294                      8                      32   5.0    0
#
#    additional_charges  ...  trips_pooled  \
# 0                 2.5  ...             1
# ...

# %%
final['nonzero_tip'] = np.where(final['tip'] > 0, 1, 0)

# %%
final['nonzero_tip'].value_counts()
# Out:
# 0    98386
# 1    21359
# Name: nonzero_tip, dtype: int64

# %%
zero = len(final[final['nonzero_tip'] == 0])
one = len(final[final['nonzero_tip'] == 1])

# %%
zero / (zero + one)
# Out:
# 0.8216292955864546

# %%
one / (zero + one)
# Out:
# 0.17837070441354544

# %%
len(final)
# Out:
# 119745
