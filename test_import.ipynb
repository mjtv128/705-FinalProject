# %%
from site import check_enableusersite
from sodapy import Socrata
import pandas as pd
import numpy as np
import requests
from datetime import datetime

# %% [markdown]
# ### Set up API

# %%
token = "dL93bWcHXE99lzC2Tyj7mJ4qR"
client = Socrata(
    "data.cityofchicago.org",
    token,
    timeout=1000000
)

# %% [markdown]
# ### 2018 Rideshare

# %%
where2018 = "trip_start_timestamp<'2019-01-01T00:00:00.000' AND trip_start_timestamp>='2018-01-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"

# Count how many records there are in 2018
record_count2018 = client.get(
    "m6dm-c72p",
    select="COUNT(*)",
    # select="trip_start_timestamp,trip_end_timestamp,trip_seconds,trip_miles,pickup_community_area,dropoff_community_area,fare,tip,additional_charges,shared_trip_authorized,trips_pooled,pickup_centroid_location,dropoff_centroid_location",
    where=where2018,
)

# %%
# Record count of 2018
record_count2018
# Out:
# [{'COUNT': '15276428'}]

# %%
# Paging through 2018 data with 1,000,000 per chunk
# Takes about 1hr
start = 0
chunk_size = 1000000
results = []
while True:
    results.extend(
        client.get(
            "m6dm-c72p",
            select="trip_start_timestamp,trip_end_timestamp,trip_seconds,trip_miles,pickup_community_area,dropoff_community_area,fare,tip,additional_charges,shared_trip_authorized,trips_pooled,pickup_centroid_location,dropoff_centroid_location",
            where=where2018,
            offset=start,
            limit=chunk_size,
        )
    )
    print("chunk: " + str(start))
    start += chunk_size
    if start > int(record_count2018[0]["COUNT"]):
        break

rideshare2018 = pd.DataFrame.from_records(results)
# Out:
# chunk: 0
# chunk: 1000000
# chunk: 2000000
# chunk: 3000000
# chunk: 4000000
# chunk: 5000000
# chunk: 6000000
# chunk: 7000000
# chunk: 8000000
# chunk: 9000000
# chunk: 10000000
# chunk: 11000000
# chunk: 12000000
# chunk: 13000000
# chunk: 14000000
# chunk: 15000000

# %%
# Change trip_start_timestamp to datetime variable
rideshare2018["trip_start_timestamp"] = pd.to_datetime(rideshare2018["trip_start_timestamp"])

# Create date variable which is only the date (remove specific time)
rideshare2018["date"] = pd.to_datetime(rideshare2018["trip_start_timestamp"]).dt.strftime("%Y-%m-%d")

# Group by date and randomly sample 0.1% of data
rideshare2018_reduced = rideshare2018.groupby("date").sample(frac=0.001)

# rideshare2018_reduced.to_csv("~/ids705/705-FinalProject/data/rideshare2018_reduced.csv")

# %% [markdown]
# ### Jan 2019 - Jan 2020 Rideshare

# %%
# where_filter for each month
where2019jan = "trip_start_timestamp>='2019-01-01T00:00:00.000' AND trip_start_timestamp<'2019-02-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"
where2019feb = "trip_start_timestamp>='2019-02-01T00:00:00.000' AND trip_start_timestamp<'2019-03-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"
where2019mar = "trip_start_timestamp>='2019-03-01T00:00:00.000' AND trip_start_timestamp<'2019-04-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"
where2019apr = "trip_start_timestamp>='2019-04-01T00:00:00.000' AND trip_start_timestamp<'2019-05-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"
where2019may = "trip_start_timestamp>='2019-05-01T00:00:00.000' AND trip_start_timestamp<'2019-06-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"
where2019jun = "trip_start_timestamp>='2019-06-01T00:00:00.000' AND trip_start_timestamp<'2019-07-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"
where2019jul = "trip_start_timestamp>='2019-07-01T00:00:00.000' AND trip_start_timestamp<'2019-08-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"
where2019aug = "trip_start_timestamp>='2019-08-01T00:00:00.000' AND trip_start_timestamp<'2019-09-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"
where2019sep = "trip_start_timestamp>='2019-09-01T00:00:00.000' AND trip_start_timestamp<'2019-10-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"
where2019oct = "trip_start_timestamp>='2019-10-01T00:00:00.000' AND trip_start_timestamp<'2019-11-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"
where2019nov = "trip_start_timestamp>='2019-11-01T00:00:00.000' AND trip_start_timestamp<'2019-12-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"
where2019dec = "trip_start_timestamp>='2019-12-01T00:00:00.000' AND trip_start_timestamp<'2020-01-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"
where2020jan = "trip_start_timestamp>='2020-01-01T00:00:00.000' AND trip_start_timestamp<'2020-02-01T00:00:00.000' AND pickup_community_area IS NOT NULL AND dropoff_community_area IS NOT NULL"

# Added to a list for convenience if running the function later in a loop (not advised, takes too long)
year2019_count = [
    where2019jan,
    where2019feb,
    where2019mar,
    where2019apr,
    where2019may,
    where2019jun,
    where2019jul,
    where2019aug,
    where2019sep,
    where2019oct,
    where2019nov,
    where2019dec,
    where2020jan,
]

# List of counts for each month
counts_bymonth = []
for month in year2019_count:
    count = client.get(
        "m6dm-c72p",
        select="COUNT(*)",
        where=month,
    )
    counts_bymonth.append(count)

# %%
def get_count(where_filter):
    """Count function. Returns in format of '[{'COUNT': 'XXXXXXX'}]'
    
    where_filter: filter condition for each month (string)
    """
    count = client.get(
        "m6dm-c72p",
        select="COUNT(*)",
        where=where_filter,
    )
    return count

# %%
def paging_data(where_filter, count):
    """Paging data with 1,000,000 per chunk.

    Play around with the chunk_size if 1 million is too large (roughly 500,000 - 1mil would be ideal).
    where_filter: filter condition (string).
    count: output from get_count function.
    
    Function returns a dataframe with selected month. 
    """
    start = 0
    chunk_size = 1000000
    results = []
    while True:
        results.extend(
            client.get(
                "m6dm-c72p",
                select="trip_start_timestamp,trip_end_timestamp,trip_seconds,trip_miles,pickup_community_area,dropoff_community_area,fare,tip,additional_charges,shared_trip_authorized,trips_pooled,pickup_centroid_location,dropoff_centroid_location",
                where=where_filter,
                offset=start,
                limit=chunk_size,
            )
        )
        start += chunk_size
        print("chunk: " + str(start))
        if start > int(count[0]["COUNT"]):
            break
    df = pd.DataFrame.from_records(results)
    return df

# %%
# Paging through data for each month
# Took 12hrs and did not finish so try not to use this
rideshare2019 = pd.DataFrame(columns=rideshare2018.columns)
for i in range(len(year2019_count)):
    dta = paging_data(year2019_count[i], counts_bymonth[i])
    rideshare2019 = pd.concat([rideshare2019, dta], axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb Cell 13' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000012?line=2'>3</a> rideshare2019 = pd.DataFrame(columns=rideshare2018.columns)
#       <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000012?line=3'>4</a> for i in range(len(year2019_count)):
# ----> <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000012?line=4'>5</a>     dta = paging_data(year2019_count[i], counts_bymonth[i])
#       <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000012?line=5'>6</a>     rideshare2019 = pd.concat([rideshare2019, dta], axis=0)
#
# /Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb Cell 12' in paging_data(where_filter, count)
#      <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000011?line=11'>12</a> results = []
#      <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000011?line=12'>13</a> while True:
#      <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000011?line=13'>14</a>     results.extend(
# ---> <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000011?line=14'>15</a>         client.get(
#      <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000011?line=15'>16</a>             "m6dm-c72p",
#      <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000011?line=16'>17</a>             select="trip_start_timestamp,trip_end_timestamp,trip_seconds,trip_miles,pickup_community_area,dropoff_community_area,fare,tip,additional_charges,shared_trip_authorized,trips_pooled,pickup_centroid_location,dropoff_centroid_location",
#      <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000011?line=17'>18</a>             where=where_filter,
#      <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000011?line=18'>19</a>             offset=start,
#      <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000011?line=19'>20</a>             limit=chunk_size,
#      <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000011?line=20'>21</a>         )
#      <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000011?line=21'>22</a>     )
#      <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000011?line=22'>23</a>     start += chunk_size
#      <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000011?line=23'>24</a>     print("chunk: " + str(start))
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sodapy/socrata.py:412, in Socrata.get(self, dataset_identifier, content_type, **kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sodapy/socrata.py?line=408'>409</a> params.update(kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sodapy/socrata.py?line=409'>410</a> params = utils.clear_empty_values(params)
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sodapy/socrata.py?line=411'>412</a> response = self._perform_request(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sodapy/socrata.py?line=412'>413</a>     "get", resource, headers=headers, params=params
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sodapy/socrata.py?line=413'>414</a> )
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sodapy/socrata.py?line=414'>415</a> return response
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sodapy/socrata.py:551, in Socrata._perform_request(self, request_type, resource, **kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sodapy/socrata.py?line=547'>548</a> # set a timeout, just to be safe
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sodapy/socrata.py?line=548'>549</a> kwargs["timeout"] = self.timeout
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sodapy/socrata.py?line=550'>551</a> response = getattr(self.session, request_type)(uri, **kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sodapy/socrata.py?line=552'>553</a> # handle errors
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sodapy/socrata.py?line=553'>554</a> if response.status_code not in (200, 202):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py:537, in Session.get(self, url, **kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=528'>529</a> r"""Sends a GET request. Returns :class:`Response` object.
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=529'>530</a>
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=530'>531</a> :param url: URL for the new :class:`Request` object.
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=531'>532</a> :param \*\*kwargs: Optional arguments that ``request`` takes.
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=532'>533</a> :rtype: requests.Response
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=533'>534</a> """
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=535'>536</a> kwargs.setdefault('allow_redirects', True)
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=536'>537</a> return self.request('GET', url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py:524, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=518'>519</a> send_kwargs = {
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=519'>520</a>     'timeout': timeout,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=520'>521</a>     'allow_redirects': allow_redirects,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=521'>522</a> }
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=522'>523</a> send_kwargs.update(settings)
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=523'>524</a> resp = self.send(prep, **send_kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=525'>526</a> return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py:677, in Session.send(self, request, **kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=673'>674</a>         pass
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=675'>676</a> if not stream:
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=676'>677</a>     r.content
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py?line=678'>679</a> return r
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py:828, in Response.content(self)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py?line=825'>826</a>         self._content = None
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py?line=826'>827</a>     else:
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py?line=827'>828</a>         self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py?line=829'>830</a> self._content_consumed = True
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py?line=830'>831</a> # don't need to release the connection; that's been handled by urllib3
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py?line=831'>832</a> # since we exhausted the data.
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py:750, in Response.iter_content.<locals>.generate()
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py?line=747'>748</a> if hasattr(self.raw, 'stream'):
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py?line=748'>749</a>     try:
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py?line=749'>750</a>         for chunk in self.raw.stream(chunk_size, decode_content=True):
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py?line=750'>751</a>             yield chunk
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py?line=751'>752</a>     except ProtocolError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py:492, in HTTPResponse.stream(self, amt, decode_content)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=475'>476</a> """
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=476'>477</a> A generator wrapper for the read() method. A call will block until
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=477'>478</a> ``amt`` bytes have been read from the connection or until the
#    (...)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=488'>489</a>     'content-encoding' header.
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=489'>490</a> """
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=490'>491</a> if self.chunked and self.supports_chunked_reads():
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=491'>492</a>     for line in self.read_chunked(amt, decode_content=decode_content):
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=492'>493</a>         yield line
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=493'>494</a> else:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py:671, in HTTPResponse.read_chunked(self, amt, decode_content)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=668'>669</a> if self.chunk_left == 0:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=669'>670</a>     break
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=670'>671</a> chunk = self._handle_chunk(amt)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=671'>672</a> decoded = self._decode(chunk, decode_content=decode_content,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=672'>673</a>                        flush_decoder=False)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=673'>674</a> if decoded:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py:626, in HTTPResponse._handle_chunk(self, amt)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=623'>624</a>     returned_chunk = value
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=624'>625</a> else:  # amt > self.chunk_left
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=625'>626</a>     returned_chunk = self._fp._safe_read(self.chunk_left)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=626'>627</a>     self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/response.py?line=627'>628</a>     self.chunk_left = None
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:626, in HTTPResponse._safe_read(self, amt)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=623'>624</a> s = []
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=624'>625</a> while amt > 0:
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=625'>626</a>     chunk = self.fp.read(min(amt, MAXAMOUNT))
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=626'>627</a>     if not chunk:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=627'>628</a>         raise IncompleteRead(b''.join(s), amt)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py?line=701'>702</a> while True:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py?line=702'>703</a>     try:
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py?line=703'>704</a>         return self._sock.recv_into(b)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py?line=704'>705</a>     except timeout:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py?line=705'>706</a>         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1236'>1237</a>     if flags != 0:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1237'>1238</a>         raise ValueError(
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1238'>1239</a>           "non-zero flags not allowed in calls to recv_into() on %s" %
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1239'>1240</a>           self.__class__)
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1240'>1241</a>     return self.read(nbytes, buffer)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1241'>1242</a> else:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1242'>1243</a>     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1096'>1097</a> try:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1097'>1098</a>     if buffer is not None:
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1098'>1099</a>         return self._sslobj.read(len, buffer)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1099'>1100</a>     else:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1100'>1101</a>         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def reduce_data(df):
    """Takes output dataframe from paging_data and select 0.1% of data from every day.
    
    Returns a dataframe which can then be concatinated with other dataframes and returned
    as .csv. 
    """
    np.random.seed(1234)
    df["trip_start_timestamp"] = pd.to_datetime(df["trip_start_timestamp"])
    df["date"] = pd.to_datetime(df["trip_start_timestamp"]).dt.strftime("%Y-%m-%d")
    df_reduced = df.groupby("date").sample(frac=0.001)
    return df_reduced

# %% [markdown]
# ### Example for paging through Jan 2019 data

# %%
df2019jan = paging_data(where2019jan, get_count(where2019jan))
df2019jan_reduced = reduce_data(df2019jan)
df2019jan_reduced.to_csv("path")

# %%
df2019jul = paging_data(where2019jul, get_count(where2019jul))
# Out:
# chunk: 1000000
# chunk: 2000000
# chunk: 3000000
# chunk: 4000000
# chunk: 5000000
# chunk: 6000000
# chunk: 7000000
# chunk: 8000000

# %%
df2019jul_reduced = reduce_data(df2019jul)

# %%
df2019jul_reduced.to_csv("jul.csv")

# %%
df2019aug = paging_data(where2019aug, get_count(where2019aug))
# Out:
# chunk: 1000000
# chunk: 2000000
# chunk: 3000000
# chunk: 4000000
# chunk: 5000000
# chunk: 6000000
# chunk: 7000000
# chunk: 8000000
# chunk: 9000000

# %%
df2019aug_reduced = reduce_data(df2019aug)

# %%
df2019aug_reduced.to_csv("aug.csv")

# %%
df2019sep = paging_data(where2019sep, get_count(where2019sep))
# Out:
# chunk: 1000000
# chunk: 2000000
# chunk: 3000000
# chunk: 4000000
# chunk: 5000000
# chunk: 6000000
# chunk: 7000000
# chunk: 8000000

# %%
df2019sep_reduced = reduce_data(df2019sep)

# %%
df2019sep_reduced.to_csv("sep.csv")

# %%
import pandas as pd

# %%
aug = pd.read_csv('./aug.csv')
aug.head()
# Out:
#    Unnamed: 0 trip_start_timestamp       trip_end_timestamp  trip_seconds  \
# 0      229556  2019-08-01 21:30:00  2019-08-01T22:00:00.000          2123
# 1      108786  2019-08-01 13:15:00  2019-08-01T14:15:00.000          3512
# 2      157951  2019-08-01 17:00:00  2019-08-01T17:15:00.000          1321
# 3       97535  2019-08-01 12:30:00  2019-08-01T13:00:00.000          1865
# 4      229507  2019-08-01 21:30:00  2019-08-01T21:45:00.000           869
#
#    trip_miles  pickup_community_area  dropoff_community_area  fare  tip  \
# 0   18.073640                     76                       8  22.5    0
# 1   16.384596                     76                      28  37.5    0
# 2    8.392442                     75                      46  15.0    0
# 3    8.831748                     77                      24  10.0    2
# 4    1.961230                      8                      32   7.5    2
#
#    additional_charges  shared_trip_authorized  trips_pooled  \
# 0                7.55                   False             1
# 1                7.55                   False             1
# 2                2.55                   False             1
# 3                2.55                   False             1
# 4                2.55                   False             1
#
#                             pickup_centroid_location  \
# 0  {'type': 'Point', 'coordinates': [-87.90303966...
# 1  {'type': 'Point', 'coordinates': [-87.90303966...
# 2  {'type': 'Point', 'coordinates': [-87.67125035...
# 3  {'type': 'Point', 'coordinates': [-87.66418824...
# 4  {'type': 'Point', 'coordinates': [-87.63576009...
#
#                            dropoff_centroid_location        date
# 0  {'type': 'Point', 'coordinates': [-87.61886835...  2019-08-01
# 1  {'type': 'Point', 'coordinates': [-87.64280846...  2019-08-01
# 2  {'type': 'Point', 'coordinates': [-87.57260730...  2019-08-01
# 3  {'type': 'Point', 'coordinates': [-87.66533765...  2019-08-01
# 4  {'type': 'Point', 'coordinates': [-87.62099291...  2019-08-01

# %%
jul = pd.read_csv('./jul.csv')
jul.head()
# Out:
#    Unnamed: 0 trip_start_timestamp       trip_end_timestamp  trip_seconds  \
# 0      119893  2019-07-01 15:45:00  2019-07-01T16:00:00.000          1517
# 1      100423  2019-07-01 14:00:00  2019-07-01T14:15:00.000          1120
# 2      172401  2019-07-01 20:15:00  2019-07-01T20:30:00.000           528
# 3       82329  2019-07-01 12:00:00  2019-07-01T12:15:00.000           980
# 4      148706  2019-07-01 18:15:00  2019-07-01T18:45:00.000          1440
#
#    trip_miles  pickup_community_area  dropoff_community_area  fare  tip  \
# 0   14.603581                     49                       8  30.0    0
# 1    6.951304                      3                       8  10.0    0
# 2    1.992832                     28                       8   5.0    1
# 3    4.968946                     77                       5   7.5    0
# 4    5.776235                     32                       7   0.0    0
#
#    additional_charges  shared_trip_authorized  trips_pooled  \
# 0                7.55                   False             1
# 1                2.55                   False             1
# 2                2.55                   False             1
# 3                2.55                   False             1
# 4                0.72                    True             2
#
#                             pickup_centroid_location  \
# 0  {'type': 'Point', 'coordinates': [-87.62336651...
# 1  {'type': 'Point', 'coordinates': [-87.65587878...
# 2  {'type': 'Point', 'coordinates': [-87.64295866...
# 3  {'type': 'Point', 'coordinates': [-87.66341640...
# 4  {'type': 'Point', 'coordinates': [-87.63274648...
#
#                            dropoff_centroid_location        date
# 0  {'type': 'Point', 'coordinates': [-87.63330803...  2019-07-01
# 1  {'type': 'Point', 'coordinates': [-87.63330803...  2019-07-01
# 2  {'type': 'Point', 'coordinates': [-87.63186394...  2019-07-01
# 3  {'type': 'Point', 'coordinates': [-87.68383494...  2019-07-01
# 4  {'type': 'Point', 'coordinates': [-87.67380723...  2019-07-01

# %%
sep = pd.read_csv('./sep.csv')
sep.head()
# len(sep)
# Out:
#    Unnamed: 0 trip_start_timestamp       trip_end_timestamp  trip_seconds  \
# 0      208531  2019-09-01 19:15:00  2019-09-01T19:30:00.000          1035
# 1       55406  2019-09-01 05:00:00  2019-09-01T05:15:00.000           849
# 2       97464  2019-09-01 11:30:00  2019-09-01T11:45:00.000           993
# 3       45640  2019-09-01 03:15:00  2019-09-01T03:30:00.000           980
# 4      107204  2019-09-01 12:15:00  2019-09-01T12:30:00.000           461
#
#    trip_miles  pickup_community_area  dropoff_community_area  fare  tip  \
# 0    4.270460                      6                      16  10.0    0
# 1    5.485975                      6                      24  15.0    0
# 2    4.817939                     33                      24   7.5    0
# 3    4.683007                      8                       6  10.0    0
# 4    1.514134                      8                       8   5.0    0
#
#    additional_charges  shared_trip_authorized  trips_pooled  \
# 0                2.55                   False             1
# 1                0.00                    True             3
# 2                2.55                   False             1
# 3                2.55                   False             1
# 4                2.55                   False             1
#
#                             pickup_centroid_location  \
# 0  {'type': 'Point', 'coordinates': [-87.65680390...
# 1  {'type': 'Point', 'coordinates': [-87.65680390...
# 2  {'type': 'Point', 'coordinates': [-87.61735800...
# 3  {'type': 'Point', 'coordinates': [-87.62621490...
# 4  {'type': 'Point', 'coordinates': [-87.63784420...
#
#                            dropoff_centroid_location        date
# 0  {'type': 'Point', 'coordinates': [-87.73089878...  2019-09-01
# 1  {'type': 'Point', 'coordinates': [-87.66474583...  2019-09-01
# 2  {'type': 'Point', 'coordinates': [-87.67094507...  2019-09-01
# 3  {'type': 'Point', 'coordinates': [-87.64302280...  2019-09-01
# 4  {'type': 'Point', 'coordinates': [-87.62665890...  2019-09-01

# %%
new = pd.concat([aug, jul, sep] , axis = 0)
new.head()
# len(new)
# Out:
#    Unnamed: 0 trip_start_timestamp       trip_end_timestamp  trip_seconds  \
# 0      229556  2019-08-01 21:30:00  2019-08-01T22:00:00.000          2123
# 1      108786  2019-08-01 13:15:00  2019-08-01T14:15:00.000          3512
# 2      157951  2019-08-01 17:00:00  2019-08-01T17:15:00.000          1321
# 3       97535  2019-08-01 12:30:00  2019-08-01T13:00:00.000          1865
# 4      229507  2019-08-01 21:30:00  2019-08-01T21:45:00.000           869
#
#    trip_miles  pickup_community_area  dropoff_community_area  fare  tip  \
# 0   18.073640                     76                       8  22.5    0
# 1   16.384596                     76                      28  37.5    0
# 2    8.392442                     75                      46  15.0    0
# 3    8.831748                     77                      24  10.0    2
# 4    1.961230                      8                      32   7.5    2
#
#    additional_charges  shared_trip_authorized  trips_pooled  \
# 0                7.55                   False             1
# 1                7.55                   False             1
# 2                2.55                   False             1
# 3                2.55                   False             1
# 4                2.55                   False             1
#
#                             pickup_centroid_location  \
# 0  {'type': 'Point', 'coordinates': [-87.90303966...
# 1  {'type': 'Point', 'coordinates': [-87.90303966...
# 2  {'type': 'Point', 'coordinates': [-87.67125035...
# 3  {'type': 'Point', 'coordinates': [-87.66418824...
# 4  {'type': 'Point', 'coordinates': [-87.63576009...
#
#                            dropoff_centroid_location        date
# 0  {'type': 'Point', 'coordinates': [-87.61886835...  2019-08-01
# 1  {'type': 'Point', 'coordinates': [-87.64280846...  2019-08-01
# 2  {'type': 'Point', 'coordinates': [-87.57260730...  2019-08-01
# 3  {'type': 'Point', 'coordinates': [-87.66533765...  2019-08-01
# 4  {'type': 'Point', 'coordinates': [-87.62099291...  2019-08-01

# %%
new.columns
# Out:
# Index(['Unnamed: 0', 'trip_start_timestamp', 'trip_end_timestamp',
#        'trip_seconds', 'trip_miles', 'pickup_community_area',
#        'dropoff_community_area', 'fare', 'tip', 'additional_charges',
#        'shared_trip_authorized', 'trips_pooled', 'pickup_centroid_location',
#        'dropoff_centroid_location', 'date'],
#       dtype='object')

# %%
new1 = new.drop('Unnamed: 0', axis=1)
new1
# Out:
#      trip_start_timestamp       trip_end_timestamp  trip_seconds  trip_miles  \
# 0     2019-08-01 21:30:00  2019-08-01T22:00:00.000          2123   18.073640
# 1     2019-08-01 13:15:00  2019-08-01T14:15:00.000          3512   16.384596
# 2     2019-08-01 17:00:00  2019-08-01T17:15:00.000          1321    8.392442
# 3     2019-08-01 12:30:00  2019-08-01T13:00:00.000          1865    8.831748
# 4     2019-08-01 21:30:00  2019-08-01T21:45:00.000           869    1.961230
# ...                   ...                      ...           ...         ...
# 7652  2019-09-30 14:45:00  2019-09-30T15:00:00.000           705    4.704218
# 7653  2019-09-30 01:15:00  2019-09-30T01:30:00.000           657    5.676132
# 7654  2019-09-30 14:15:00  2019-09-30T14:30:00.000           700    2.411363
# 7655  2019-09-30 20:45:00  2019-09-30T21:15:00.000          1759   14.830000
# 7656  2019-09-30 09:45:00  2019-09-30T09:45:00.000           716    1.611987
#
#       pickup_community_area  dropoff_community_area  fare  tip  \
# 0                        76                       8  22.5    0
# 1                        76                      28  37.5    0
# 2                        75                      46  15.0    0
# 3                        77                      24  10.0    2
# 4                         8                      32   7.5    2
# ...                     ...                     ...   ...  ...
# 7652                     42                      38  10.0    3
# 7653                     33                      41  10.0    0
# 7654                      8                       8   7.5    0
# 7655                     76                      77  22.5    6
# 7656                      8                      32   7.5    0
#
#       additional_charges  shared_trip_authorized  trips_pooled  \
# 0                   7.55                   False             1
# 1                   7.55                   False             1
# 2                   2.55                   False             1
# 3                   2.55                   False             1
# 4                   2.55                   False             1
# ...                  ...                     ...           ...
# 7652                2.55                   False             1
# 7653                2.55                   False             1
# 7654                2.55                   False             1
# 7655                7.55                   False             1
# 7656                2.55                   False             1
#
#                                pickup_centroid_location  \
# 0     {'type': 'Point', 'coordinates': [-87.90303966...
# 1     {'type': 'Point', 'coordinates': [-87.90303966...
# 2     {'type': 'Point', 'coordinates': [-87.67125035...
# 3     {'type': 'Point', 'coordinates': [-87.66418824...
# 4     {'type': 'Point', 'coordinates': [-87.63576009...
# ...                                                 ...
# 7652  {'type': 'Point', 'coordinates': [-87.57994824...
# 7653  {'type': 'Point', 'coordinates': [-87.62033462...
# 7654  {'type': 'Point', 'coordinates': [-87.63576009...
# 7655  {'type': 'Point', 'coordinates': [-87.91362459...
# 7656  {'type': 'Point', 'coordinates': [-87.63186394...
#
#                               dropoff_centroid_location        date
# 0     {'type': 'Point', 'coordinates': [-87.61886835...  2019-08-01
# 1     {'type': 'Point', 'coordinates': [-87.64280846...  2019-08-01
# 2     {'type': 'Point', 'coordinates': [-87.57260730...  2019-08-01
# 3     {'type': 'Point', 'coordinates': [-87.66533765...  2019-08-01
# 4     {'type': 'Point', 'coordinates': [-87.62099291...  2019-08-01
# ...                                                 ...         ...
# 7652  {'type': 'Point', 'coordinates': [-87.60894927...  2019-09-30
# 7653  {'type': 'Point', 'coordinates': [-87.59231085...  2019-09-30
# 7654  {'type': 'Point', 'coordinates': [-87.61886835...  2019-09-30
# 7655  {'type': 'Point', 'coordinates': [-87.66341640...  2019-09-30
# 7656  {'type': 'Point', 'coordinates': [-87.62217293...  2019-09-30
#
# [23655 rows x 14 columns]

# %%
# new.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb Cell 33' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/michellevan/Documents/MIDS/Spring22/ML/final/705-FinalProject/test_import.ipynb#ch0000033?line=0'>1</a> new.reset_index(inplace=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:5833, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=5826'>5827</a>         if lab is not None:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=5827'>5828</a>             # if we have the codes, extract the values with a mask
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=5828'>5829</a>             level_values = algorithms.take(
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=5829'>5830</a>                 level_values, lab, allow_fill=True, fill_value=lev._na_value
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=5830'>5831</a>             )
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=5832'>5833</a>         new_obj.insert(0, name, level_values)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=5834'>5835</a> new_obj.index = new_index
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=5835'>5836</a> if not inplace:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:4434, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=4427'>4428</a>     raise ValueError(
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=4428'>4429</a>         "Cannot specify 'allow_duplicates=True' when "
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=4429'>4430</a>         "'self.flags.allows_duplicate_labels' is False."
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=4430'>4431</a>     )
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=4431'>4432</a> if not allow_duplicates and column in self.columns:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=4432'>4433</a>     # Should this be a different kind of error??
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=4433'>4434</a>     raise ValueError(f"cannot insert {column}, already exists")
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=4434'>4435</a> if not isinstance(loc, int):
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py?line=4435'>4436</a>     raise TypeError("loc must be int")
#
# ValueError: cannot insert level_0, already exists

# %%
new1.head()
# Out:
#   trip_start_timestamp       trip_end_timestamp  trip_seconds  trip_miles  \
# 0  2019-08-01 21:30:00  2019-08-01T22:00:00.000          2123   18.073640
# 1  2019-08-01 13:15:00  2019-08-01T14:15:00.000          3512   16.384596
# 2  2019-08-01 17:00:00  2019-08-01T17:15:00.000          1321    8.392442
# 3  2019-08-01 12:30:00  2019-08-01T13:00:00.000          1865    8.831748
# 4  2019-08-01 21:30:00  2019-08-01T21:45:00.000           869    1.961230
#
#    pickup_community_area  dropoff_community_area  fare  tip  \
# 0                     76                       8  22.5    0
# 1                     76                      28  37.5    0
# 2                     75                      46  15.0    0
# 3                     77                      24  10.0    2
# 4                      8                      32   7.5    2
#
#    additional_charges  shared_trip_authorized  trips_pooled  \
# 0                7.55                   False             1
# 1                7.55                   False             1
# 2                2.55                   False             1
# 3                2.55                   False             1
# 4                2.55                   False             1
#
#                             pickup_centroid_location  \
# 0  {'type': 'Point', 'coordinates': [-87.90303966...
# 1  {'type': 'Point', 'coordinates': [-87.90303966...
# 2  {'type': 'Point', 'coordinates': [-87.67125035...
# 3  {'type': 'Point', 'coordinates': [-87.66418824...
# 4  {'type': 'Point', 'coordinates': [-87.63576009...
#
#                            dropoff_centroid_location        date
# 0  {'type': 'Point', 'coordinates': [-87.61886835...  2019-08-01
# 1  {'type': 'Point', 'coordinates': [-87.64280846...  2019-08-01
# 2  {'type': 'Point', 'coordinates': [-87.57260730...  2019-08-01
# 3  {'type': 'Point', 'coordinates': [-87.66533765...  2019-08-01
# 4  {'type': 'Point', 'coordinates': [-87.62099291...  2019-08-01

# %%
new1.reset_index(inplace=True)

# %%
new1.tail()
# Out:
#        index trip_start_timestamp       trip_end_timestamp  trip_seconds  \
# 23650   7652  2019-09-30 14:45:00  2019-09-30T15:00:00.000           705
# 23651   7653  2019-09-30 01:15:00  2019-09-30T01:30:00.000           657
# 23652   7654  2019-09-30 14:15:00  2019-09-30T14:30:00.000           700
# 23653   7655  2019-09-30 20:45:00  2019-09-30T21:15:00.000          1759
# 23654   7656  2019-09-30 09:45:00  2019-09-30T09:45:00.000           716
#
#        trip_miles  pickup_community_area  dropoff_community_area  fare  tip  \
# 23650    4.704218                     42                      38  10.0    3
# 23651    5.676132                     33                      41  10.0    0
# 23652    2.411363                      8                       8   7.5    0
# 23653   14.830000                     76                      77  22.5    6
# 23654    1.611987                      8                      32   7.5    0
#
#        additional_charges  shared_trip_authorized  trips_pooled  \
# 23650                2.55                   False             1
# 23651                2.55                   False             1
# 23652                2.55                   False             1
# 23653                7.55                   False             1
# 23654                2.55                   False             1
#
#                                 pickup_centroid_location  \
# 23650  {'type': 'Point', 'coordinates': [-87.57994824...
# 23651  {'type': 'Point', 'coordinates': [-87.62033462...
# 23652  {'type': 'Point', 'coordinates': [-87.63576009...
# 23653  {'type': 'Point', 'coordinates': [-87.91362459...
# 23654  {'type': 'Point', 'coordinates': [-87.63186394...
#
#                                dropoff_centroid_location        date
# 23650  {'type': 'Point', 'coordinates': [-87.60894927...  2019-09-30
# 23651  {'type': 'Point', 'coordinates': [-87.59231085...  2019-09-30
# 23652  {'type': 'Point', 'coordinates': [-87.61886835...  2019-09-30
# 23653  {'type': 'Point', 'coordinates': [-87.66341640...  2019-09-30
# 23654  {'type': 'Point', 'coordinates': [-87.62217293...  2019-09-30

# %%
new1.drop('index', inplace=True, axis=1)

# %%
new1.tail()
# Out:
#       trip_start_timestamp       trip_end_timestamp  trip_seconds  trip_miles  \
# 23650  2019-09-30 14:45:00  2019-09-30T15:00:00.000           705    4.704218
# 23651  2019-09-30 01:15:00  2019-09-30T01:30:00.000           657    5.676132
# 23652  2019-09-30 14:15:00  2019-09-30T14:30:00.000           700    2.411363
# 23653  2019-09-30 20:45:00  2019-09-30T21:15:00.000          1759   14.830000
# 23654  2019-09-30 09:45:00  2019-09-30T09:45:00.000           716    1.611987
#
#        pickup_community_area  dropoff_community_area  fare  tip  \
# 23650                     42                      38  10.0    3
# 23651                     33                      41  10.0    0
# 23652                      8                       8   7.5    0
# 23653                     76                      77  22.5    6
# 23654                      8                      32   7.5    0
#
#        additional_charges  shared_trip_authorized  trips_pooled  \
# 23650                2.55                   False             1
# 23651                2.55                   False             1
# 23652                2.55                   False             1
# 23653                7.55                   False             1
# 23654                2.55                   False             1
#
#                                 pickup_centroid_location  \
# 23650  {'type': 'Point', 'coordinates': [-87.57994824...
# 23651  {'type': 'Point', 'coordinates': [-87.62033462...
# 23652  {'type': 'Point', 'coordinates': [-87.63576009...
# 23653  {'type': 'Point', 'coordinates': [-87.91362459...
# 23654  {'type': 'Point', 'coordinates': [-87.63186394...
#
#                                dropoff_centroid_location        date
# 23650  {'type': 'Point', 'coordinates': [-87.60894927...  2019-09-30
# 23651  {'type': 'Point', 'coordinates': [-87.59231085...  2019-09-30
# 23652  {'type': 'Point', 'coordinates': [-87.61886835...  2019-09-30
# 23653  {'type': 'Point', 'coordinates': [-87.66341640...  2019-09-30
# 23654  {'type': 'Point', 'coordinates': [-87.62217293...  2019-09-30

# %%
new.drop(['level_0', 'index', 'Unnamed: 0'], axis=1, inplace=True)

# %%
new.head()
# Out:
#   trip_start_timestamp       trip_end_timestamp  trip_seconds  trip_miles  \
# 0  2019-08-01 21:30:00  2019-08-01T22:00:00.000          2123   18.073640
# 1  2019-08-01 13:15:00  2019-08-01T14:15:00.000          3512   16.384596
# 2  2019-08-01 17:00:00  2019-08-01T17:15:00.000          1321    8.392442
# 3  2019-08-01 12:30:00  2019-08-01T13:00:00.000          1865    8.831748
# 4  2019-08-01 21:30:00  2019-08-01T21:45:00.000           869    1.961230
#
#    pickup_community_area  dropoff_community_area  fare  tip  \
# 0                     76                       8  22.5    0
# 1                     76                      28  37.5    0
# 2                     75                      46  15.0    0
# 3                     77                      24  10.0    2
# 4                      8                      32   7.5    2
#
#    additional_charges  shared_trip_authorized  trips_pooled  \
# 0                7.55                   False             1
# 1                7.55                   False             1
# 2                2.55                   False             1
# 3                2.55                   False             1
# 4                2.55                   False             1
#
#                             pickup_centroid_location  \
# 0  {'type': 'Point', 'coordinates': [-87.90303966...
# 1  {'type': 'Point', 'coordinates': [-87.90303966...
# 2  {'type': 'Point', 'coordinates': [-87.67125035...
# 3  {'type': 'Point', 'coordinates': [-87.66418824...
# 4  {'type': 'Point', 'coordinates': [-87.63576009...
#
#                            dropoff_centroid_location        date
# 0  {'type': 'Point', 'coordinates': [-87.61886835...  2019-08-01
# 1  {'type': 'Point', 'coordinates': [-87.64280846...  2019-08-01
# 2  {'type': 'Point', 'coordinates': [-87.57260730...  2019-08-01
# 3  {'type': 'Point', 'coordinates': [-87.66533765...  2019-08-01
# 4  {'type': 'Point', 'coordinates': [-87.62099291...  2019-08-01

# %%
new.to_csv("jul_to_aug.csv")

# %%
new1.to_csv('jul_to_aug1.csv')
